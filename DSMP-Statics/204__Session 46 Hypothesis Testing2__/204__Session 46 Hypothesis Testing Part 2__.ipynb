# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tits = sns.load_dataset("titanic")
tits.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
tits["age"].mean()
# Out:
# 29.69911764705882

# %%
pop = tits["age"].dropna()

# %%
sample_age = pop.sample(25).values
sample_age
# Out:
# array([18. , 21. ,  8. , 30. ,  5. ,  5. , 19. , 30. , 35. , 27. , 40. ,
#        32. , 14. , 61. , 40. , 42. , 24. , 51. , 22. , 34.5, 18. , 54. ,
#        45. , 16. , 25. ])

# %%
# H0 - Mean Age is 35 
# H1 - Mean is less than 35 

# Aplha = 0.05
# n = 25

# %%
# no std so we will apply T Test 

# since here data we cannot is a normal distribution so we cannot directly assume it is a normal distribution 

# So we will use shapiro wilk test. 

# Shapiro wilk Test tell - it takes sample and return whether it will form a noraml distribtuin or not

# shapiro se agar value 
    # p value from shaprio < 0.05   -> not normal distribution
    # p value from shaprio > 0.05   -> yes normal distribution

# %%
from scipy.stats import shapiro
shapiro_age = shapiro(sample_age)

# if(shapiro_age < 0.05):
#     print("Not Normal Distribution")
# else:
#     print("Yes Normal Distribution")


shapiro_age
# Out:
# ShapiroResult(statistic=0.9747826744186215, pvalue=0.766405179651003)

# %%
pop_mean = 35

# %%
# t = (X' - mue)/S/root(n)


import scipy.stats as stats
t_statics , p_val = stats.ttest_1samp(sample_age , pop_mean)

print("T Statics -", t_statics) 
print("P Value -" , p_val/2)
# Out:
# T Statics - -2.120935191423097
# P Value - 0.02222646396825273

# %%
if p_val < 0.05:
    print("Reject Null Hypotheses")
else:
    print("Fail to Reject null hypothesis")
# Out:
# Reject Null Hypotheses

# %%
pop.mean()
# Out:
# 29.69911764705882

# %%
# yes it is less than 35 so it is proved .

# %% [markdown]
# <h1>Independent 2 sample test</h1>

# %%
# The Shapiro-Wilk test returns two values: the test statistic (W) and the p-value.
# If the p-value is greater than your chosen significance level (a = 0.05),
# you can assume the data comes from a normally distributed population.
# If the p-value is less than or jequal to the significance level, the normality assumption is not met,
# and you should consider applying a data transformation or using a non-parametric test like the Mann-Whitney U test.

from scipy.stats import shapiro

# Input the data as lists
desktop_users = [12, 15, 18, 16, 20, 17, 14, 22, 19, 21, 23, 18, 25, 17, 16, 24, 20, 19, 22, 18, 15, 14, 23, 16, 12, 21, 19, 17, 20, 14]
mobile_users = [10, 12, 14, 13, 16, 15, 11, 17, 14, 16, 18, 14, 20, 15, 14, 19, 16, 15, 17, 14, 12, 11, 18, 15, 10, 16, 15, 13, 16, 11]

# Perform the Shapiro-Wilk test for both desktop and mobile users
shapiro_desktop = shapiro(desktop_users)
shapiro_mobile = shapiro(mobile_users)

print("Shapiro-Wilk test for desktop users:", shapiro_desktop)
print("Shapiro-Wilk test for mobile users:", shapiro_mobile)
# Out:
# Shapiro-Wilk test for desktop users: ShapiroResult(statistic=0.9783115512411942, pvalue=0.7791003299808725)
# Shapiro-Wilk test for mobile users: ShapiroResult(statistic=0.9714355768676655, pvalue=0.5791606602037616)

# %%
# yes p value > 0.05 so following normal distribution

# %%
# Lavene Test for variance

# %%
# If the p-value from Levene's test is greater than your chosen significance level (a = 0.05), you can assume equal variances
# If the p-value is less than or equal to the significance level, the assumption of equal variances is not met,
# and you should consider using Welch's t-test instead of the regular independent two-sample t-test.

from scipy.stats import levene

# Input the data as lists
desktop_users = [12, 15, 18, 16, 20, 17, 14, 22, 19, 21, 23, 18, 25, 17, 16, 24, 20, 19, 22, 18, 15, 14, 23, 16, 12, 21, 19, 17, 20, 14]
mobile_users = [10, 12, 14, 13, 16, 15, 11, 17, 14, 16, 18, 14, 20, 15, 14, 19, 16, 15, 17, 14, 12, 11, 18, 15, 10, 16, 15, 13, 16, 11]

# Perform Levene's test
levene_test = levene(desktop_users, mobile_users)
print(levene_test)
# Out:
# LeveneResult(statistic=2.94395488191752, pvalue=0.09153720526741761)

# %%
# if lavene test value < 0.05 then 
    # variance of a != varaince of b
# Above case variance is true

# %%
# t = (x1 - x2)/root of s1 square / n1 + s2 square / n2

# t = 5.25

# %%
# but sir taken -5.25 why ? 
tt = -5.25
# df = n1+n2-2

df = 58

# %%
from scipy.stats import t
cdf = t.cdf(tt , df)
cdf*2 # why *2 dont get
# Out:
# 2.256369746933224e-06

# %%
# equlas to 0 so we can say 
    # reject my null hypothesis

# %%
# 2 sample t Test on null hyp

# %%
# avg age of male > avg age of females

# %%
h0 = # avg age of male == avg age of females
h1 = # avg age of male > avg age of females

# so these is a relation between age and gender
# Out:
#   Cell In[103], line 1
#     h0 = # avg age of male == avg age of females
#          ^
# SyntaxError: invalid syntax

# %%
tits
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
males = tits[tits["sex"] == "male"]["age"].dropna()
males

females = tits[tits["sex"] == "female"]["age"].dropna()
females
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 879    56.0
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# Name: age, Length: 261, dtype: float64

# %%
males
# Out:
# 0      22.0
# 4      35.0
# 6      54.0
# 7       2.0
# 12     20.0
#        ...
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: age, Length: 453, dtype: float64

# %%
sample_male=males.sample(25)
sample_females=females.sample(25)

alpha = 0.05

# %%
# h0 = # avg age of male == avg age of females
# h1 = # avg age of male > avg age of females

# # so these is a relation between age and gender

# %%
from scipy.stats import shapiro

shapiro_males = shapiro(sample_male)
shapiro_females = shapiro(sample_females)

print("Shapiro Wilk for males: " , shapiro_males)
print("Shapiro Wilk for females: " , shapiro_females)
# Out:
# Shapiro Wilk for males:  ShapiroResult(statistic=0.9678471981241742, pvalue=0.5910990631777826)
# Shapiro Wilk for females:  ShapiroResult(statistic=0.9920038926934163, pvalue=0.9989475869364434)

# %%
levene_test = levene(sample_male,sample_females)
levene_test

# yes greter than 0.05 so variance is same lgbg
# Out:
# LeveneResult(statistic=0.1264670658682632, pvalue=0.723681737279875)

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_ind(sample_male, sample_females)

print("t-statistic:", t_statistic)
print("p-value:", p_value/2)
# Out:
# t-statistic: -1.0544512713012864
# p-value: 0.14847763189389185

# %%
# p val > 0.05 cannot reject

# %%
if p_val < 0.05:
    print("Reject Null Hypotheseis")
else:
    print("Dont Reject Null Hypotheseis")
# Out:
# Reject Null Hypotheseis

# %%
males.mean() , females.mean()
# Out:
# (30.72664459161148, 27.915708812260537)

# %% [markdown]
# <h1>Paired sample 2 test</h1>

# %%
# difference ka normal distribution h ki nahi check krna 

# agar normally dis h toh hum 
    # We find sample mean and sample standard deviation.

# %%
# h0 - same
# h1 - before>after

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

before = np.array([80, 92, 75, 68, 85, 78, 73, 90, 70, 88, 76, 84, 82, 77, 91])
after = np.array([78, 93, 81, 67, 88, 76, 74, 91, 69, 88, 77, 81, 80, 79, 88])

differences = before - after

# %%
plt.hist(differences)
plt.title("Histogram of Weight Differences")
plt.xlabel("Weight Differences (kg)")
plt.ylabel("Frequency")
plt. show()

shapiro_test = stats.shapiro(differences)
print("Shapiro-Wilk test:", shapiro_test)
# Out:
# Shapiro-Wilk test: ShapiroResult(statistic=0.9220571486009433, pvalue=0.2070477898690044)

# %%
# pval > 0.05 , so it follow normal dis

# %%
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)

n = len(differences)
t_statistic = mean_diff / (std_diff / np.sqrt(n))
df = n - 1

t_statistic
# Out:
# -0.10482848367219182

# %%
alpha = 0.05
p_value = stats.t.cdf(t_statistic, df)

# %%
p_value 
# pval > 0.05 , so null hyp
# Out:
# 0.45899948531425433

# %%
# null hyp cannt be rejected so it does not means it is correct
