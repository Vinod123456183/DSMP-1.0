# %%
# distance from origin -> euclidean norm  
import numpy as np  
# Define an n-dimensional vector A 
A = np.array([1, 2, 3, 4,6,7,8,9,10,11,112,12])  
# Calculate the Euclidean distance from the origin (L2 norm) 
distance = np.linalg.norm(A)  
print("Euclidean distance from the origin:", distance)
# Out:
# Euclidean distance from the origin: 114.75626344561765

# %%
# to find euclidean distance in n-D 
import numpy as np  


# Define two n-dimensional vectors A and B 
A = np.array([1, 2, 3, 4, 5]) 
B = np.array([6,7, 8, 9, 10])  
# Calculate the difference vector 
difference = A - B  
difference
# Out:
# array([-5, -5, -5, -5, -5])

# %%
# Calculate the Euclidean distance between A and B (L2 norm of the difference) 
distance = np.linalg.norm(difference)  
print("Euclidean distance between A and B:", distance)
# Out:
# Euclidean distance between A and B: 11.180339887498949

# %%
import numpy as np 
import matplotlib.pyplot as plt  
# Generate random 2D data with 100 points 
data = np.random.rand(100,  2)
data
# Out:
# array([[0.07550749, 0.5640731 ],
#        [0.88951594, 0.98764988],
#        [0.17966675, 0.80640703],
#        [0.84752299, 0.48408588],
#        [0.52169813, 0.10940459],
#        [0.02508001, 0.91095083],
#        [0.18526529, 0.41063124],
#        [0.00577834, 0.07012288],
#        [0.60915259, 0.57596943],
#        [0.83537906, 0.02835048],
#        [0.3417055 , 0.48115213],
#        [0.46936927, 0.88922106],
#        [0.58306666, 0.22235087],
#        [0.48151887, 0.79155968],
#        [0.56449681, 0.40104435],
#        [0.92049279, 0.99480961],
#        [0.80230581, 0.633355  ],
#        [0.5982502 , 0.86146684],
#        [0.97654996, 0.46922807],
#        [0.74871203, 0.25873286],
#        [0.13041334, 0.01792295],
#        [0.3307504 , 0.65483865],
#        [0.1231631 , 0.73159283],
#        [0.40026741, 0.81255608],
#        [0.2782545 , 0.26478431],
#        [0.78323154, 0.57153017],
#        [0.60071575, 0.1490272 ],
#        [0.76156915, 0.71693589],
#        [0.82905262, 0.26057421],
#        [0.95147668, 0.60883687],
#        [0.15447776, 0.19445128],
#        [0.59033843, 0.51806479],
#        [0.76344619, 0.83335004],
#        [0.49696873, 0.00927073],
#        [0.28020354, 0.36554814],
#        [0.55799431, 0.84116603],
#        [0.25591634, 0.60027228],
#        [0.9080528 , 0.3382301 ],
#        [0.14228418, 0.56340946],
#        [0.22456235, 0.87703518],
#        [0.36194   , 0.13782672],
#        [0.6688312 , 0.99935776],
#        [0.55361974, 0.55519944],
#        [0.75991332, 0.3302076 ],
#        [0.63613217, 0.36056719],
#        [0.23495174, 0.20182832],
#        [0.84483915, 0.09349548],
#        [0.19833074, 0.3389215 ],
#        [0.54200608, 0.18390382],
#        [0.85044432, 0.50303922],
#        [0.13714746, 0.45853322],
#        [0.96764533, 0.6118374 ],
#        [0.54597194, 0.40590065],
#        [0.26753476, 0.21025443],
#        [0.87507334, 0.34030715],
#        [0.43480581, 0.19898286],
#        [0.12269883, 0.5249968 ],
#        [0.3869776 , 0.08042864],
#        [0.79197508, 0.85711127],
#        [0.81464702, 0.82018355],
#        [0.17631646, 0.66528605],
#        [0.42124899, 0.28028927],
#        [0.99252896, 0.88609461],
#        [0.45010596, 0.35893206],
#        [0.9261843 , 0.83891639],
#        [0.6405309 , 0.09886686],
#        [0.33800499, 0.0608576 ],
#        [0.80245816, 0.73645624],
#        [0.33874914, 0.96929215],
#        [0.54928479, 0.02874145],
#        [0.55425222, 0.51747357],
#        [0.69395019, 0.83523434],
#        [0.53624949, 0.91641917],
#        [0.69909665, 0.64961902],
#        [0.59339183, 0.40584509],
#        [0.03933293, 0.25228755],
#        [0.28901036, 0.67930766],
#        [0.89037978, 0.10290849],
#        [0.29570712, 0.40603776],
#        [0.69635344, 0.39205922],
#        [0.4815175 , 0.75100775],
#        [0.4908681 , 0.29949082],
#        [0.79545012, 0.45391197],
#        [0.36398012, 0.55002233],
#        [0.95354539, 0.2608345 ],
#        [0.59522091, 0.53696412],
#        [0.8884265 , 0.31396657],
#        [0.5830197 , 0.75135553],
#        [0.87345568, 0.57973503],
#        [0.98029435, 0.83998584],
#        [0.14688135, 0.27389117],
#        [0.85340214, 0.6976762 ],
#        [0.62212606, 0.85456634],
#        [0.94659241, 0.96704628],
#        [0.38789161, 0.45339621],
#        [0.31511624, 0.1148018 ],
#        [0.72877546, 0.99657141],
#        [0.42929176, 0.88851322],
#        [0.86321844, 0.58574945],
#        [0.82719126, 0.85552834]])

# %%
# Plot the original data 
plt.figure(figsize=(12, 6))  
plt.subplot(1, 2, 1) 
plt.scatter(data[:, 0], data[:, 1], label="Original Data") 
plt.xlabel("X-axis") 
plt.ylabel("Y-axis") 
plt.title("Before Mean Centering") 
plt.axhline(0, color='black', linewidth=0.5) 
plt.axvline(0, color='black', linewidth=0.5) 
plt.legend()

# %%
# Calculate the mean of the data along each dimension 
data_mean = np.mean(data, axis=0)  
print(data_mean) # Perform mean centering 
centered_data = data - data_mean
# Out:
# [0.55269061 0.51198785]

# %%
# Plot the mean-centered data
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1],
            label="Mean-Centered Data", color="orange")

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")

# Add axis lines
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.legend()
plt.tight_layout()
plt.show()

# %%
# Perform mean centering
data_mean = np.mean(data, axis=0)
centered_data = data - data_mean

# Plot the original and mean-centered data
plt.figure(figsize=(12, 6))

# --- Original Data ---
plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1], label="Original Data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Before Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# --- Mean-Centered Data ---
plt.subplot(1, 2, 2)
plt.scatter(centered_data[:, 0], centered_data[:, 1],
            label="Mean-Centered Data", color="orange")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("After Mean Centering")
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np  
# Define three vectors 
A = np.array([1, 2, 3]) 
B = np.array([4, 5, 6])  
print(np.dot(A, B)) 
print(A@B)
# Out:
# 32
# 32

# %%
import numpy as np  

# Define three vectors 
A = np.array([1, 2, 3]) 
B = np.array([4, 5, 6]) 
C = np.array([7, 8, 9])  
# Calculate dot product using numpy.dot() function 
dot_product_AB = np.dot(A, B) 
dot_product_BA = np.dot(B, A)  
print(dot_product_AB) 
print(dot_product_BA)  
# Check commutative property: A . B = B . A 
if dot_product_AB == dot_product_BA:
    print("The dot product is commutative.") 
else: 
    print("The dot product is not commutative. ")
# Out:
# 32
# 32
# The dot product is commutative.

# %%
# Check distributive property: A · (B + C) = A · B + A · C

dot_product_A_BC = np.dot(A, B + C)
dot_product_AB_plus_AC = np.dot(A, B) + np.dot(A, C)

print(dot_product_A_BC)
print(dot_product_AB_plus_AC)

if np.allclose(dot_product_A_BC, dot_product_AB_plus_AC):
    print("The dot product is distributive.")
else:
    print("The dot product is not distributive.")
# Out:
# 82
# 82
# The dot product is distributive.

# %%
import numpy as np  

# Define three vectors
A = np.array([1, 2, 3])
B = np.array([-4, -5, -6])
C = np.array([5, 5, 5])

# Cosine similarity function
def cosine_sim(x, y):
    return np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

# Calculate cosine similarities
cos_AB = cosine_sim(A, B)
cos_AC = cosine_sim(A, C)

print("Cosine similarity between A and B:", cos_AB)
print("Cosine similarity between A and C:", cos_AC)
# Out:
# Cosine similarity between A and B: -0.9746318461970762
# Cosine similarity between A and C: 0.9258200997725513
